# %% [markdown]
# # 3.

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
#create path 
path = r'C:\Users\kickw\OneDrive\Documents\Instacart Basket Analysis'
#import orders_products_combined
df_orders_products_combined = pd.read_pickle (r'C:\Users\kickw\OneDrive\Documents\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl')
#import products df
df_prods = pd.read_csv (r'C:\Users\kickw\OneDrive\Documents\Instacart Basket Analysis\02 Data\Prepared Data\products_checked.csv')

# %% [markdown]
# # 4.

# %%
#check shape of df
df_orders_products_combined.shape
# Out:
# (32434489, 13)

# %% [markdown]
# # 5.

# %%
#check df shape
df_prods.shape
# Out:
# (49693, 6)

# %%
#preview df_prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods_drop= df_prods.drop(columns= ['Unnamed: 0'])

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0           0             0   2539329        1             1
# 1           0             0   2539329        1             1
# 2           0             0   2539329        1             1
# 3           0             0   2539329        1             1
# 4           0             0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   2                  8                     NaN
# 2                   2                  8                     NaN
# 3                   2                  8                     NaN
# 4                   2                  8                     NaN
#
#   customer_status  product_id  add_to_cart_order  reordered _merge
# 0    New Customer         196                  1          0   both
# 1    New Customer       14084                  2          0   both
# ...

# %%
df_combined= df_orders_products_combined.drop(columns=['_merge', 'Unnamed: 0', 'Unnamed: 0.1'])

# %%
df_combined
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order     customer_status  \
# 0                         8                     NaN        New Customer
# 1                         8                     NaN        New Customer
# ...

# %%
#merge df_orders_products_combined with products df
df_orders_products_merged = df_combined.merge(df_prods_drop, on = 'product_id', indicator = True )

# %% [markdown]
# # 6.

# %%
#view new df with merge flag column
df_orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order     customer_status  product_id  add_to_cart_order  \
# 0                     NaN        New Customer         196                  1
# 1                    15.0  Returning Customer         196                  1
# 2                    21.0  Returning Customer         196                  1
# 3                    29.0  Returning Customer         196                  1
# 4                    28.0  Returning Customer         196                  1
#
# ...

# %%
df_orders_products_merged.shape
# Out:
# (32434212, 15)

# %% [markdown]
# # 7.

# %%
# Export data to pkl
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
