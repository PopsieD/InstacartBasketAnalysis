# %% [markdown]
# # 4.7 Section Overview

# %% [markdown]
# ## Importing

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
#importing data
path = r'C:\Users\kickw\OneDrive\Documents\Instacart Basket Analysis'
ords_prods_merged = pd.read_pickle(r'C:\Users\kickw\OneDrive\Documents\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged.pkl')

# %%
#working with a subset of only the first 1000000 rows
df = ords_prods_merged[:1000000]
df.shape
# Out:
# (1000000, 15)

# %%
ords_prods_merged.shape
# Out:
# (32434212, 15)

# %%
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order     customer_status  product_id  add_to_cart_order  \
# 0                     NaN        New Customer         196                  1
# 1                    15.0  Returning Customer         196                  1
# 2                    21.0  Returning Customer         196                  1
# 3                    29.0  Returning Customer         196                  1
# 4                    28.0  Returning Customer         196                  1
#
# ...

# %% [markdown]
# ## user defined functions

# %%
#user defined function
def price_label(row):
    if row['prices']<= 5:
        return 'Low-range product'
    elif (row['prices']>5) and (row['prices']<= 15):
        return 'Mid-range product'
    elif row['prices']> 15:
        return 'High-range product'
    else: return 'Not enough data'

# %%
#implementing new column
df['price_range']= df.apply(price_label, axis=1)
# Out:
# <ipython-input-6-d1f11f397b01>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range']= df.apply(price_label, axis=1)

# %%
#view value counts
df['price_range'].value_counts(dropna= False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
#finding max price in subset
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## loc() function

# %%
#loc() function of subset
df.loc[df['prices']>15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\kickw\anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\kickw\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df.loc[(df['prices']<= 15) & (df['prices']>5), 'price_range_loc']= 'Mid-range product'

# %%
df.loc[df['prices']<=5, 'price_range_loc']= 'Low-range procuct'

# %%
df['price_range_loc'].value_counts(dropna= False)
# Out:
# Mid-range product    756450
# Low-range procuct    243550
# Name: price_range_loc, dtype: int64

# %%
#loc() function of entire df
ords_prods_merged.loc[ords_prods_merged['prices']>15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices']<= 15) & (ords_prods_merged['prices']>5), 'price_range_loc']= 'Mid-range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices']<=5, 'price_range_loc']= 'Low-range procuct'

# %%
ords_prods_merged['price_range_loc'].value_counts(dropna= False)
# Out:
# Mid-range product     21890146
# Low-range procuct     10126384
# High-range product      417682
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## For-loops

# %%
#frequency of orders placed in each day of the week
ords_prods_merged['orders_day_of_week'].value_counts(dropna= False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: orders_day_of_week, dtype: int64

# %%
# print how busy each day usually is
result = []
for value in ords_prods_merged["orders_day_of_week"]:
    if value== 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#make the results list a new column in df
ords_prods_merged['busiest_day']= result

# %%
#results frequency
ords_prods_merged['busiest_day'].value_counts(dropna= False)
# Out:
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: busiest_day, dtype: int64

# %% [markdown]
# # 4.7 Section Task

# %% [markdown]
# ## 2.

# %%
#frequency of orders placed in each day of the week
ords_prods_merged['orders_day_of_week'].value_counts(dropna= False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: orders_day_of_week, dtype: int64

# %%
# condition for string variable 'busiest_days'
results = []
for value in ords_prods_merged["orders_day_of_week"]:
    if (value==0 or value==1):
        results.append("Busiest days")
    elif (value == 4 or value== 3):
       results.append("Slowest days")
    else:
       results.append("Regularly busy")

# %%
results
# Out:
# ['Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
ords_prods_merged['Busiest_days']= results

# %%
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order     customer_status  product_id  add_to_cart_order  \
# 0                     NaN        New Customer         196                  1
# 1                    15.0  Returning Customer         196                  1
# 2                    21.0  Returning Customer         196                  1
# 3                    29.0  Returning Customer         196                  1
# 4                    28.0  Returning Customer         196                  1
#
# ...

# %%
merged_with_cats= ords_prods_merged.drop(columns= ['busiest_day'])

# %%
merged_with_cats.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order     customer_status  product_id  add_to_cart_order  \
# 0                     NaN        New Customer         196                  1
# 1                    15.0  Returning Customer         196                  1
# 2                    21.0  Returning Customer         196                  1
# 3                    29.0  Returning Customer         196                  1
# 4                    28.0  Returning Customer         196                  1
#
# ...

# %% [markdown]
# ## 3.

# %%
#value counts
merged_with_cats['Busiest_days'].value_counts(dropna= False)
# Out:
# Regularly busy    12927461
# Busiest days      11875462
# Slowest days       7631289
# Name: Busiest_days, dtype: int64

# %%
merged_with_cats.shape
# Out:
# (32434212, 17)

# %% [markdown]
# There are no missing values in this column.

# %% [markdown]
# ## 4.

# %%
#frequency of orders placed in each hour
merged_with_cats['order_hour_of_day'].value_counts(dropna= False)
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %%
# condition for string variable 'busiest_days'
result_hours = []
for value in merged_with_cats["orders_day_of_week"]:
    if (value==10, value==11, value==15, value==14, value==13, value==12):
        result_hours.append("Most orders")
    elif (value == 0, value==1, value==5, value==2, value==4, value==3):
        result_hours.append("Fewest orders")
    else:
        result_hours.append("Average orders")

# %%
merged_with_cats['busiest_period_of_day']= result_hours

# %% [markdown]
# ## 5.

# %%
#frequency of busiest hours
merged_with_cats['busiest_period_of_day'].value_counts(dropna= False)
# Out:
# Most orders    32434212
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ## 7.

# %%
merged_with_cats.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_category_labels.pkl'))
